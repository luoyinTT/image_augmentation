0.08788895227993568, 0.5: 0.09825714356705267, 0.6: 0.10106096192437253, 0.7: 0.11498129031726517, 0.8: 0.09967551183873832, 0.9: 0.10150648111390748}, 'yolo_block.1.1.0.conv.weights': {0.1: -0.00019634376389229257, 0.2: -4.215421634967879e-06, 0.3: -0.001055976254991298, 0.4: -0.0011096510322576405, 0.5: -0.0019591304406269753, 0.6: -0.0005847029999586633, 0.7: 0.005792700201164314, 0.8: 0.026316998154577834, 0.9: 0.04846291784922955}, 'yolo_output.1.conv.weights': {0.1: 0.03049071977602063, 0.2: 0.04126711207562492, 0.3: 0.05016621294269732, 0.4: 0.061225565190852795, 0.5: 0.061405870235401214, 0.6: 0.08560064208886037, 0.7: 0.09791723487516457, 0.8: 0.09757411620496198, 0.9: 0.09041395383108093}, 'yolo_block.1.2.conv.weights': {0.1: -0.0009831667510125104, 0.2: -0.0011871414451395197, 0.3: -0.0006708359709422145, 0.4: 4.039339856563702e-05, 0.5: 0.002026930006010891, 0.6: 0.010435717420443412, 0.7: 0.02730628814632678, 0.8: 0.04324954825954907, 0.9: 0.05053931473777634}, 'yolo_block.0.0.0.conv.weights': {0.1: 3.090298337968879e-06, 0.2: -9.624730984029177e-05, 0.3: 0.00036147219310233333, 0.4: 0.0022216584480156103, 0.5: 0.00463289465109538, 0.6: 0.008478491329582307, 0.7: 0.025324571471302827, 0.8: 0.10888723443143987, 0.9: 0.6848432344832219}}

# %%
line_name = list(file_dict.keys())
print(line_name)
print(len(line_name))
print(list(file_dict[line_name[0]].values()))
x_data = list(file_dict[line_name[0]].keys())
# Out:
# ['yolo_output.2.conv.weights', 'yolo_block.0.1.1.conv.weights', 'yolo_block.0.1.spp.conv.conv.weights', 'yolo_block.0.tip.conv.weights', 'yolo_block.0.0.1.conv.weights', 'yolo_transition.0.conv.weights', 'yolo_transition.1.conv.weights', 'yolo_block.2.1.0.conv.weights', 'yolo_block.2.tip.conv.weights', 'yolo_block.1.0.1.conv.weights', 'yolo_block.2.2.conv.weights', 'yolo_block.2.0.0.conv.weights', 'conv1_2_weights', 'conv1_3_weights', 'yolo_output.0.conv.weights', 'yolo_block.0.1.0.conv.weights', 'yolo_block.1.1.1.conv.weights', 'yolo_block.0.2.conv.weights', 'yolo_block.1.0.0.conv.weights', 'yolo_block.2.1.1.conv.weights', 'yolo_block.2.0.1.conv.weights', 'yolo_block.1.tip.conv.weights', 'yolo_block.1.1.0.conv.weights', 'yolo_output.1.conv.weights', 'yolo_block.1.2.conv.weights', 'yolo_block.0.0.0.conv.weights']
# 26
# ...

# %%
# fig, ax = plt.subplots()
for i in range(len(line_name)):
    plt.plot(x_data, list(file_dict[line_name[i]].values()), label = line_name[i])
# lgnd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
# plt.legend(loc = 'upper right')
# fig.subplots_adjust(right=0.75)
plt.show()

# %%
x_data_1 = list(file_dict[line_name[0]].keys())
x_data = [str(i) for i in x_data_1]
line = Line()
line.add_xaxis(x_data)
for i in range(len(line_name)):
    y = list(file_dict[line_name[i]].values())
    line.add_yaxis(line_name[i],y)
line.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
line.set_global_opts(
                            datazoom_opts= [opts.DataZoomOpts(range_start=0, range_end=100,is_zoom_lock=False)],
                             legend_opts=opts.LegendOpts(type_="scroll", pos_left="20%", orient="horizontal"))
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bbf22ceece1d47739d74feaaa341fa8e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bbf22ceece1d47739d74feaaa341fa8e = echarts.init(
#                     document.getElementById('bbf22ceece1d47739d74feaaa341fa8e'), 'white', {renderer: 'canvas'});
#                 var option_bbf22ceece1d47739d74feaaa341fa8e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
